# %% [markdown]
# <a href="https://colab.research.google.com/github/bibek1997/Alphabet-Classification/blob/master/siamese.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import numpy as np
import pandas as pd
import scipy.misc
from PIL import Image
import pickle
import os
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
import time

import tensorflow as tf
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model

from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.initializers import glorot_uniform

from keras.engine.topology import Layer
from keras.regularizers import l2
from keras import backend as K

from sklearn.utils import shuffle

import numpy.random as rng

# %%
train_folder = "images_background/"
val_folder = 'images_evaluation/'
save_path = 'data/'

# %%
def loadimgs(path,n = 0):
    '''
    path => Path of train directory or test directory
    '''
    X=[]
    y = []
    cat_dict = {}
    lang_dict = {}
    curr_y = n
    # we load every alphabet seperately so we can isolate them later
    for alphabet in os.listdir(path):
        print("loading alphabet: " + alphabet)
        lang_dict[alphabet] = [curr_y,None]
        alphabet_path = os.path.join(path,alphabet)
        # every letter/category has it's own column in the array, so  load seperately
        for letter in os.listdir(alphabet_path):
            cat_dict[curr_y] = (alphabet, letter)
            category_images=[]
            letter_path = os.path.join(alphabet_path, letter)
            # read all the images in the current category
            for filename in os.listdir(letter_path):
                image_path = os.path.join(letter_path, filename)
                image = Image.open(image_path)
                category_images.append(image)
                y.append(curr_y)
            try:
                X.append(np.stack(category_images))
            # edge case  - last one
            except ValueError as e:
                print(e)
                print("error - category_images:", category_images)
            curr_y += 1
            lang_dict[alphabet][1] = curr_y - 1
    y = np.vstack(y)
    X = np.stack(X)
    return X,y,lang_dict

# %%
X,y,c=loadimgs(train_folder)
# Out:
# loading alphabet: N_Ko
# loading alphabet: Japanese_(hiragana)
# loading alphabet: Asomtavruli_(Georgian)
# loading alphabet: Latin
# loading alphabet: Inuktitut_(Canadian_Aboriginal_Syllabics)
# loading alphabet: Arcadian
# loading alphabet: Japanese_(katakana)
# loading alphabet: Futurama
# loading alphabet: Burmese_(Myanmar)
# loading alphabet: Blackfoot_(Canadian_Aboriginal_Syllabics)
# loading alphabet: Syriac_(Estrangelo)
# loading alphabet: Mkhedruli_(Georgian)
# loading alphabet: Braille
# loading alphabet: Ojibwe_(Canadian_Aboriginal_Syllabics)
# loading alphabet: Greek
# loading alphabet: Bengali
# loading alphabet: Grantha
# loading alphabet: Sanskrit
# loading alphabet: Anglo-Saxon_Futhorc
# loading alphabet: Gujarati
# loading alphabet: Malay_(Jawi_-_Arabic)
# loading alphabet: Balinese
# loading alphabet: Armenian
# loading alphabet: Cyrillic
# loading alphabet: Early_Aramaic
# loading alphabet: Alphabet_of_the_Magi
# loading alphabet: Hebrew
# loading alphabet: Korean
# loading alphabet: Tifinagh
# loading alphabet: Tagalog

# %%
X.shape
# Out:
# (964, 20, 105, 105)

# %%
y.shape
# Out:
# (19280, 1)

# %%
c.keys() # 'c' for categories
# Out:
# dict_keys(['N_Ko', 'Japanese_(hiragana)', 'Asomtavruli_(Georgian)', 'Latin', 'Inuktitut_(Canadian_Aboriginal_Syllabics)', 'Arcadian', 'Japanese_(katakana)', 'Futurama', 'Burmese_(Myanmar)', 'Blackfoot_(Canadian_Aboriginal_Syllabics)', 'Syriac_(Estrangelo)', 'Mkhedruli_(Georgian)', 'Braille', 'Ojibwe_(Canadian_Aboriginal_Syllabics)', 'Greek', 'Bengali', 'Grantha', 'Sanskrit', 'Anglo-Saxon_Futhorc', 'Gujarati', 'Malay_(Jawi_-_Arabic)', 'Balinese', 'Armenian', 'Cyrillic', 'Early_Aramaic', 'Alphabet_of_the_Magi', 'Hebrew', 'Korean', 'Tifinagh', 'Tagalog'])

# %%
c['Alphabet_of_the_Magi']
# Out:
# [810, 829]

# %%
c['Anglo-Saxon_Futhorc']
# Out:
# [573, 601]

# %%
with open(os.path.join(save_path,"train.pickle"), "wb") as f:
    pickle.dump((X,c),f)

# %%
Xval,yval,cval=loadimgs(val_folder)
# Out:
# loading alphabet: Manipuri
# loading alphabet: Aurek-Besh
# loading alphabet: Atlantean
# loading alphabet: Gurmukhi
# loading alphabet: Oriya
# loading alphabet: Glagolitic
# loading alphabet: Old_Church_Slavonic_(Cyrillic)
# loading alphabet: Sylheti
# loading alphabet: Tengwar
# loading alphabet: Angelic
# loading alphabet: Ge_ez
# loading alphabet: Kannada
# loading alphabet: Tibetan
# loading alphabet: Keble
# loading alphabet: ULOG
# loading alphabet: Mongolian
# loading alphabet: Syriac_(Serto)
# loading alphabet: Avesta
# loading alphabet: Atemayar_Qelisayer
# loading alphabet: Malayalam

# %%
with open(os.path.join(save_path,"val.pickle"), "wb") as f:
    pickle.dump((Xval,cval),f)

# %%
def get_batch(batch_size,s="train"):
    """
    Create batch of n pairs, half same class, half different class
    """
    if s == 'train':
        X = Xtrain
        categories = train_classes
    else:
        X = Xval
        categories = val_classes
    n_classes, n_examples, w, h = X.shape
    
    # randomly sample several classes to use in the batch
    categories = rng.choice(n_classes,size=(batch_size,),replace=False)
    
    # initialize 2 empty arrays for the input image batch
    pairs=[np.zeros((batch_size, h, w,1)) for i in range(2)]
    
    # initialize vector for the targets
    targets=np.zeros((batch_size,))
    
    # make one half of it '1's, so 2nd half of batch has same class
    targets[batch_size//2:] = 1
    for i in range(batch_size):
        category = categories[i]
        idx_1 = rng.randint(0, n_examples)
        pairs[0][i,:,:,:] = X[category, idx_1].reshape(w, h, 1)
        idx_2 = rng.randint(0, n_examples)
        
        # pick images of same class for 1st half, different for 2nd
        if i >= batch_size // 2:
            category_2 = category  
        else: 
            # add a random number to the category modulo n classes to ensure 2nd image has a different category
            category_2 = (category + rng.randint(1,n_classes)) % n_classes
        
        pairs[1][i,:,:,:] = X[category_2,idx_2].reshape(w, h,1)
    
    return pairs, targets

# %%
def generate(batch_size, s="train"):
    """
    a generator for batches, so model.fit_generator can be used.
    """
    while True:
        pairs, targets = get_batch(batch_size,s)
    yield (pairs, targets)

# %%
def initialize_weights(shape, name=None):
    """
        The paper, http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
        suggests to initialize CNN layer weights with mean as 0.0 and standard deviation of 0.01
    """
    return np.random.normal(loc = 0.0, scale = 1e-2, size = shape)

# %%
def initialize_bias(shape, name=None):
    """
        The paper, http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
        suggests to initialize CNN layer bias with mean as 0.5 and standard deviation of 0.01
    """
    return np.random.normal(loc = 0.5, scale = 1e-2, size = shape)

# %%
def get_siamese_model(input_shape):
    """
        Model architecture
    """
    
    # Define the tensors for the two input images
    left_input = Input(input_shape)
    right_input = Input(input_shape)
    
    # Convolutional Neural Network
    model = Sequential()
    model.add(Conv2D(64, (10,10), activation='relu', input_shape=input_shape,
                   kernel_initializer=initialize_weights, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(128, (7,7), activation='relu',
                     kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(128, (4,4), activation='relu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(256, (4,4), activation='relu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(Flatten())
    model.add(Dense(4096, activation='sigmoid',
                   kernel_regularizer=l2(1e-3),
                   kernel_initializer=initialize_weights,bias_initializer=initialize_bias))
    
    # Generate the encodings (feature vectors) for the two images
    encoded_l = model(left_input)
    encoded_r = model(right_input)
    
    # Add a customized layer to compute the absolute difference between the encodings
    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    L1_distance = L1_layer([encoded_l, encoded_r])
    
    # Add a dense layer with a sigmoid unit to generate the similarity score
    prediction = Dense(1,activation='sigmoid',bias_initializer=initialize_bias)(L1_distance)
    
    # Connect the inputs with the outputs
    siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)
    
    # return the model
    return siamese_net

# %%
model = get_siamese_model((105, 105, 1))
model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0615 13:28:33.235083 140174479943552 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0615 13:28:33.285419 140174479943552 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0615 13:28:33.332709 140174479943552 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0615 13:28:36.123241 140174479943552 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 105, 105, 1)  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 105, 105, 1)  0
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 4096)         38947648    input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4096)         0           sequential_1[1][0]
#                                                                  sequential_1[2][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            4097        lambda_1[0][0]
# ==================================================================================================
# Total params: 38,951,745
# Trainable params: 38,951,745
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
optimizer = Adam(lr = 0.00006)
model.compile(loss="binary_crossentropy",optimizer=optimizer)
# Out:
# W0615 13:28:42.285567 140174479943552 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0615 13:28:42.293633 140174479943552 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0615 13:28:42.300152 140174479943552 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
with open(os.path.join(save_path, "train.pickle"), "rb") as f:
    (Xtrain, train_classes) = pickle.load(f)
    
print("Training alphabets: \n")
print(list(train_classes.keys()))
# Out:
# Training alphabets:
#
# ['N_Ko', 'Japanese_(hiragana)', 'Asomtavruli_(Georgian)', 'Latin', 'Inuktitut_(Canadian_Aboriginal_Syllabics)', 'Arcadian', 'Japanese_(katakana)', 'Futurama', 'Burmese_(Myanmar)', 'Blackfoot_(Canadian_Aboriginal_Syllabics)', 'Syriac_(Estrangelo)', 'Mkhedruli_(Georgian)', 'Braille', 'Ojibwe_(Canadian_Aboriginal_Syllabics)', 'Greek', 'Bengali', 'Grantha', 'Sanskrit', 'Anglo-Saxon_Futhorc', 'Gujarati', 'Malay_(Jawi_-_Arabic)', 'Balinese', 'Armenian', 'Cyrillic', 'Early_Aramaic', 'Alphabet_of_the_Magi', 'Hebrew', 'Korean', 'Tifinagh', 'Tagalog']

# %%
with open(os.path.join(save_path, "val.pickle"), "rb") as f:
    (Xval, val_classes) = pickle.load(f)

print("Validation alphabets:", end="\n\n")
print(list(val_classes.keys()))
# Out:
# Validation alphabets:
#
# ['Manipuri', 'Aurek-Besh', 'Atlantean', 'Gurmukhi', 'Oriya', 'Glagolitic', 'Old_Church_Slavonic_(Cyrillic)', 'Sylheti', 'Tengwar', 'Angelic', 'Ge_ez', 'Kannada', 'Tibetan', 'Keble', 'ULOG', 'Mongolian', 'Syriac_(Serto)', 'Avesta', 'Atemayar_Qelisayer', 'Malayalam']

# %%
def get_batch(batch_size,s="train"):
    """Create batch of n pairs, half same class, half different class"""
    if s == 'train':
        X = Xtrain
        categories = train_classes
    else:
        X = Xval
        categories = val_classes
    n_classes, n_examples, w, h = X.shape

    # randomly sample several classes to use in the batch
    categories = rng.choice(n_classes,size=(batch_size,),replace=False)
    
    # initialize 2 empty arrays for the input image batch
    pairs=[np.zeros((batch_size, h, w,1)) for i in range(2)]
    
    # initialize vector for the targets
    targets=np.zeros((batch_size,))
    
    # make one half of it '1's, so 2nd half of batch has same class
    targets[batch_size//2:] = 1
    for i in range(batch_size):
        category = categories[i]
        idx_1 = rng.randint(0, n_examples)
        pairs[0][i,:,:,:] = X[category, idx_1].reshape(w, h, 1)
        idx_2 = rng.randint(0, n_examples)
        
        # pick images of same class for 1st half, different for 2nd
        if i >= batch_size // 2:
            category_2 = category  
        else: 
            # add a random number to the category modulo n classes to ensure 2nd image has a different category
            category_2 = (category + rng.randint(1,n_classes)) % n_classes
        
        pairs[1][i,:,:,:] = X[category_2,idx_2].reshape(w, h,1)
    
    return pairs, targets

# %%
def generate(batch_size, s="train"):
    """a generator for batches, so model.fit_generator can be used. """
    while True:
        pairs, targets = get_batch(batch_size,s)
        yield (pairs, targets)

# %%
def make_oneshot_task(N, s="val", language=None):
    """Create pairs of test image, support set for testing N way one-shot learning. """
    if s == 'train':
        X = Xtrain
        categories = train_classes
    else:
        X = Xval
        categories = val_classes
    n_classes, n_examples, w, h = X.shape
    
    indices = rng.randint(0, n_examples,size=(N,))
    if language is not None: # if language is specified, select characters for that language
        low, high = categories[language]
        if N > high - low:
            raise ValueError("This language ({}) has less than {} letters".format(language, N))
        categories = rng.choice(range(low,high),size=(N,),replace=False)

    else: # if no language specified just pick a bunch of random letters
        categories = rng.choice(range(n_classes),size=(N,),replace=False)            
    true_category = categories[0]
    ex1, ex2 = rng.choice(n_examples,replace=False,size=(2,))
    test_image = np.asarray([X[true_category,ex1,:,:]]*N).reshape(N, w, h,1)
    support_set = X[categories,indices,:,:]
    support_set[0,:,:] = X[true_category,ex2]
    support_set = support_set.reshape(N, w, h,1)
    targets = np.zeros((N,))
    targets[0] = 1
    targets, test_image, support_set = shuffle(targets, test_image, support_set)
    pairs = [test_image,support_set]

    return pairs, targets

# %%
def test_oneshot(model, N, k, s = "val", verbose = 0):
    """Test average N way oneshot learning accuracy of a siamese neural net over k one-shot tasks"""
    n_correct = 0
    if verbose:
        print("Evaluating model on {} random {} way one-shot learning tasks ... \n".format(k,N))
    for i in range(k):
        inputs, targets = make_oneshot_task(N,s)
        probs = model.predict(inputs)
        if np.argmax(probs) == np.argmax(targets):
            n_correct+=1
    percent_correct = (100.0 * n_correct / k)
    if verbose:
        print("Got an average of {}% {} way one-shot learning accuracy \n".format(percent_correct,N))
    return percent_correct

# %%
# !unzip weights.zip
# Out:
# Archive:  weights.zip
#    creating: weights/

# %%
# Hyper parameters
evaluate_every = 200 # interval for evaluating on one-shot tasks
batch_size = 32
n_iter = 20000 # No. of training iterations
N_way = 20 # how many classes for testing one-shot tasks
n_val = 250 # how many one-shot tasks to validate on
best = -1

# %%
model_path = 'weights/'

# %%
print("Starting training process!")
print("-------------------------------------")
t_start = time.time()
for i in range(1, n_iter+1):
    (inputs,targets) = get_batch(batch_size)
    loss = model.train_on_batch(inputs, targets)
    if i % evaluate_every == 0:
        print("\n ------------- \n")
        print("Time for {0} iterations: {1} mins".format(i, (time.time()-t_start)/60.0))
        print("Train Loss: {0}".format(loss)) 
        val_acc = test_oneshot(model, N_way, n_val, verbose=True)
        model.save_weights(os.path.join(model_path, 'weights.{}.h5'.format(i)))
        if val_acc >= best:
            print("Current best: {0}, previous best: {1}".format(val_acc, best))
            best = val_acc
# Out:
# Starting training process!
# -------------------------------------
# W0615 13:36:45.599319 140174479943552 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#  -------------
#
# Time for 200 iterations: 0.489103639125824 mins
# Train Loss: 1.565435767173767
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 26.4% 20 way one-shot learning accuracy
#
# Current best: 26.4, previous best: -1
#
#  -------------
#
# Time for 400 iterations: 0.8604960838953654 mins
# Train Loss: 0.9222679734230042
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 19.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 600 iterations: 1.235609801610311 mins
# Train Loss: 0.771441638469696
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 30.0% 20 way one-shot learning accuracy
#
# Current best: 30.0, previous best: 26.4
#
#  -------------
#
# Time for 800 iterations: 1.615317956606547 mins
# Train Loss: 0.5625434517860413
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 26.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1000 iterations: 1.999904731909434 mins
# Train Loss: 0.5840540528297424
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 30.4% 20 way one-shot learning accuracy
#
# Current best: 30.4, previous best: 30.0
#
#  -------------
#
# Time for 1200 iterations: 2.3788657546043397 mins
# Train Loss: 0.5133920907974243
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 28.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1400 iterations: 2.7555243889490764 mins
# Train Loss: 0.5037039518356323
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 30.8% 20 way one-shot learning accuracy
#
# Current best: 30.8, previous best: 30.4
#
#  -------------
#
# Time for 1600 iterations: 3.1333753148714703 mins
# Train Loss: 0.48577144742012024
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 37.6% 20 way one-shot learning accuracy
#
# Current best: 37.6, previous best: 30.8
#
#  -------------
#
# Time for 1800 iterations: 3.51233895222346 mins
# Train Loss: 0.4299374520778656
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 38.0% 20 way one-shot learning accuracy
#
# Current best: 38.0, previous best: 37.6
#
#  -------------
#
# Time for 2000 iterations: 3.8914193749427795 mins
# Train Loss: 0.51457679271698
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 38.4% 20 way one-shot learning accuracy
#
# Current best: 38.4, previous best: 38.0
#
#  -------------
#
# Time for 2200 iterations: 4.269156273206075 mins
# Train Loss: 0.36284971237182617
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 44.8% 20 way one-shot learning accuracy
#
# Current best: 44.8, previous best: 38.4
#
#  -------------
#
# Time for 2400 iterations: 4.647320930163065 mins
# Train Loss: 0.47044461965560913
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 38.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 2600 iterations: 5.025072721640269 mins
# Train Loss: 0.38605350255966187
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 47.2% 20 way one-shot learning accuracy
#
# Current best: 47.2, previous best: 44.8
#
#  -------------
#
# Time for 2800 iterations: 5.4035692850748696 mins
# Train Loss: 0.5147166848182678
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 45.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 3000 iterations: 5.783194887638092 mins
# Train Loss: 0.2804916799068451
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 46.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 3200 iterations: 6.174163623650869 mins
# Train Loss: 0.4177827537059784
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 48.8% 20 way one-shot learning accuracy
#
# Current best: 48.8, previous best: 47.2
#
#  -------------
#
# Time for 3400 iterations: 6.554627819856008 mins
# Train Loss: 0.3845895230770111
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 48.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 3600 iterations: 6.933486274878184 mins
# Train Loss: 0.6044126152992249
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 51.6% 20 way one-shot learning accuracy
#
# Current best: 51.6, previous best: 48.8
#
#  -------------
#
# Time for 3800 iterations: 7.312829569975535 mins
# Train Loss: 0.3475620448589325
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 48.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 4000 iterations: 7.6923091292381285 mins
# Train Loss: 0.31485337018966675
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 51.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 4200 iterations: 8.071803251902262 mins
# Train Loss: 0.27609559893608093
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 60.4% 20 way one-shot learning accuracy
#
# Current best: 60.4, previous best: 51.6
#
#  -------------
#
# Time for 4400 iterations: 8.451778109868368 mins
# Train Loss: 0.31811264157295227
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 55.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 4600 iterations: 8.830998198191326 mins
# Train Loss: 0.2361229807138443
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 60.4% 20 way one-shot learning accuracy
#
# Current best: 60.4, previous best: 60.4
#
#  -------------
#
# Time for 4800 iterations: 9.210802944501241 mins
# Train Loss: 0.29878687858581543
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 58.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 5000 iterations: 9.590291953086853 mins
# Train Loss: 0.29650548100471497
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 58.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 5200 iterations: 9.969650506973267 mins
# Train Loss: 0.2585379183292389
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 60.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 5400 iterations: 10.349109538396199 mins
# Train Loss: 0.3400767147541046
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 54.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 5600 iterations: 10.728111052513123 mins
# Train Loss: 0.3417474925518036
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 63.2% 20 way one-shot learning accuracy
#
# Current best: 63.2, previous best: 60.4
#
#  -------------
#
# Time for 5800 iterations: 11.107220300038655 mins
# Train Loss: 0.3252618610858917
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 64.8% 20 way one-shot learning accuracy
#
# Current best: 64.8, previous best: 63.2
#
#  -------------
#
# Time for 6000 iterations: 11.486864531040192 mins
# Train Loss: 0.2172737419605255
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 59.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 6200 iterations: 11.865348704655965 mins
# Train Loss: 0.21762210130691528
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 61.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 6400 iterations: 12.246291613578796 mins
# Train Loss: 0.40352663397789
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 58.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 6600 iterations: 12.628472896416982 mins
# Train Loss: 0.35793256759643555
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 63.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 6800 iterations: 13.010142536958059 mins
# Train Loss: 0.27598676085472107
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 65.6% 20 way one-shot learning accuracy
#
# Current best: 65.6, previous best: 64.8
#
#  -------------
#
# Time for 7000 iterations: 13.3905620098114 mins
# Train Loss: 0.19413380324840546
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 64.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 7200 iterations: 13.770120278994243 mins
# Train Loss: 0.326824426651001
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 64.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 7400 iterations: 14.149638398488362 mins
# Train Loss: 0.21141916513442993
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 66.0% 20 way one-shot learning accuracy
#
# Current best: 66.0, previous best: 65.6
#
#  -------------
#
# Time for 7600 iterations: 14.529308529694875 mins
# Train Loss: 0.2838625907897949
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 61.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 7800 iterations: 14.90975631872813 mins
# Train Loss: 0.25951531529426575
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 64.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 8000 iterations: 15.289695624510447 mins
# Train Loss: 0.18517199158668518
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 64.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 8200 iterations: 15.669317698478698 mins
# Train Loss: 0.17158398032188416
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 58.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 8400 iterations: 16.04944082101186 mins
# Train Loss: 0.2372199296951294
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 66.0% 20 way one-shot learning accuracy
#
# Current best: 66.0, previous best: 66.0
#
#  -------------
#
# Time for 8600 iterations: 16.42967490355174 mins
# Train Loss: 0.1922915279865265
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 66.0% 20 way one-shot learning accuracy
#
# Current best: 66.0, previous best: 66.0
#
#  -------------
#
# Time for 8800 iterations: 16.80923073689143 mins
# Train Loss: 0.28473377227783203
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 64.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 9000 iterations: 17.189580182234447 mins
# Train Loss: 0.29747599363327026
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 68.4% 20 way one-shot learning accuracy
#
# Current best: 68.4, previous best: 66.0
#
#  -------------
#
# Time for 9200 iterations: 17.569642301400503 mins
# Train Loss: 0.19713996350765228
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 70.0% 20 way one-shot learning accuracy
#
# Current best: 70.0, previous best: 68.4
#
#  -------------
#
# Time for 9400 iterations: 17.94967878262202 mins
# Train Loss: 0.33838823437690735
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 68.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 9600 iterations: 18.329926216602324 mins
# Train Loss: 0.21003268659114838
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 66.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 9800 iterations: 18.70830748875936 mins
# Train Loss: 0.26708588004112244
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 67.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 10000 iterations: 19.087397027015687 mins
# Train Loss: 0.3335763216018677
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 70.4% 20 way one-shot learning accuracy
#
# Current best: 70.4, previous best: 70.0
#
#  -------------
#
# Time for 10200 iterations: 19.466510951519012 mins
# Train Loss: 0.15817715227603912
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.4% 20 way one-shot learning accuracy
#
# Current best: 72.4, previous best: 70.4
#
#  -------------
#
# Time for 10400 iterations: 19.84522686402003 mins
# Train Loss: 0.140125572681427
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 70.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 10600 iterations: 20.22375879685084 mins
# Train Loss: 0.16212058067321777
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 10800 iterations: 20.60312673250834 mins
# Train Loss: 0.18500328063964844
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 66.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 11000 iterations: 20.981684903303783 mins
# Train Loss: 0.1479048728942871
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.8% 20 way one-shot learning accuracy
#
# Current best: 72.8, previous best: 72.4
#
#  -------------
#
# Time for 11200 iterations: 21.362674311796823 mins
# Train Loss: 0.27544254064559937
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 68.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 11400 iterations: 21.74176270564397 mins
# Train Loss: 0.14665809273719788
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 68.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 11600 iterations: 22.1211199204127 mins
# Train Loss: 0.31181514263153076
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 70.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 11800 iterations: 22.500311271349588 mins
# Train Loss: 0.27454647421836853
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 67.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 12000 iterations: 22.880036393801372 mins
# Train Loss: 0.27296581864356995
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 70.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 12200 iterations: 23.25931513706843 mins
# Train Loss: 0.3606833219528198
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.8% 20 way one-shot learning accuracy
#
# Current best: 72.8, previous best: 72.8
#
#  -------------
#
# Time for 12400 iterations: 23.63908120393753 mins
# Train Loss: 0.15000304579734802
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 65.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 12600 iterations: 24.01842528184255 mins
# Train Loss: 0.16065122187137604
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 69.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 12800 iterations: 24.398831768830618 mins
# Train Loss: 0.3858031928539276
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 64.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 13000 iterations: 24.777376838525136 mins
# Train Loss: 0.15547366440296173
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 74.8% 20 way one-shot learning accuracy
#
# Current best: 74.8, previous best: 72.8
#
#  -------------
#
# Time for 13200 iterations: 25.15611276626587 mins
# Train Loss: 0.3309117257595062
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 13400 iterations: 25.535723074277243 mins
# Train Loss: 0.31145352125167847
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 68.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 13600 iterations: 25.9144673426946 mins
# Train Loss: 0.2426951378583908
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 69.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 13800 iterations: 26.294148310025534 mins
# Train Loss: 0.2637622058391571
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 70.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 14000 iterations: 26.672218422094982 mins
# Train Loss: 0.28554201126098633
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 14200 iterations: 27.051704768339793 mins
# Train Loss: 0.1780930757522583
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 68.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 14400 iterations: 27.430511764685313 mins
# Train Loss: 0.1643747240304947
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 75.2% 20 way one-shot learning accuracy
#
# Current best: 75.2, previous best: 74.8
#
#  -------------
#
# Time for 14600 iterations: 27.809332474072775 mins
# Train Loss: 0.239170640707016
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 69.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 14800 iterations: 28.18819810549418 mins
# Train Loss: 0.17570075392723083
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 67.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 15000 iterations: 28.567711985111238 mins
# Train Loss: 0.24082797765731812
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 68.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 15200 iterations: 28.946194231510162 mins
# Train Loss: 0.2849048972129822
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 68.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 15400 iterations: 29.325329752763114 mins
# Train Loss: 0.2859117090702057
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 15600 iterations: 29.704345122973123 mins
# Train Loss: 0.1516193300485611
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 75.6% 20 way one-shot learning accuracy
#
# Current best: 75.6, previous best: 75.2
#
#  -------------
#
# Time for 15800 iterations: 30.083875234921774 mins
# Train Loss: 0.19738683104515076
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 16000 iterations: 30.46306473016739 mins
# Train Loss: 0.19677311182022095
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 73.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 16200 iterations: 30.841704539457957 mins
# Train Loss: 0.26287394762039185
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 64.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 16400 iterations: 31.220609005292257 mins
# Train Loss: 0.12276095151901245
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 71.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 16600 iterations: 31.599600613117218 mins
# Train Loss: 0.15608765184879303
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 69.2% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 16800 iterations: 31.97789667050044 mins
# Train Loss: 0.20075641572475433
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 68.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 17000 iterations: 32.35812904834747 mins
# Train Loss: 0.2434692680835724
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 74.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 17200 iterations: 32.73689943552017 mins
# Train Loss: 0.19364461302757263
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 17400 iterations: 33.115926464398704 mins
# Train Loss: 0.13867449760437012
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 74.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 17600 iterations: 33.49527897834778 mins
# Train Loss: 0.1699810028076172
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 74.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 17800 iterations: 33.87341790994008 mins
# Train Loss: 0.1794358491897583
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 70.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 18000 iterations: 34.25243766307831 mins
# Train Loss: 0.2932567894458771
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 70.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 18200 iterations: 34.63076336781184 mins
# Train Loss: 0.15314196050167084
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 73.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 18400 iterations: 35.01002080043157 mins
# Train Loss: 0.15717729926109314
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 77.2% 20 way one-shot learning accuracy
#
# Current best: 77.2, previous best: 75.6
#
#  -------------
#
# Time for 18600 iterations: 35.388746321201324 mins
# Train Loss: 0.23423747718334198
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 74.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 18800 iterations: 35.76795159975688 mins
# Train Loss: 0.16405384242534637
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 70.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 19000 iterations: 36.14704328378041 mins
# Train Loss: 0.2522260546684265
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 67.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 19200 iterations: 36.52613121668498 mins
# Train Loss: 0.24230390787124634
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 71.6% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 19400 iterations: 36.90508290529251 mins
# Train Loss: 0.16476662456989288
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.8% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 19600 iterations: 37.28365906476974 mins
# Train Loss: 0.33290785551071167
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 74.4% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 19800 iterations: 37.66268255710602 mins
# Train Loss: 0.19180907309055328
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 70.0% 20 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 20000 iterations: 38.04155017534892 mins
# Train Loss: 0.21409010887145996
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Got an average of 72.8% 20 way one-shot learning accuracy

# %%
model.load_weights(os.path.join(model_path, "weights.20000.h5"))

# %%
def nearest_neighbour_correct(pairs,targets):
    """returns 1 if nearest neighbour gets the correct answer for a one-shot task
        given by (pairs, targets)"""
    L2_distances = np.zeros_like(targets)
    for i in range(len(targets)):
        L2_distances[i] = np.sum(np.sqrt(pairs[0][i]**2 - pairs[1][i]**2))
    if np.argmin(L2_distances) == np.argmax(targets):
        return 1
    return 0

# %%
def test_nn_accuracy(N_ways,n_trials):
    """Returns accuracy of NN approach """
    print("Evaluating nearest neighbour on {} unique {} way one-shot learning tasks ...".format(n_trials,N_ways))
    n_right = 0
    
    for i in range(n_trials):
        pairs,targets = make_oneshot_task(N_ways,"val")
        correct = nearest_neighbour_correct(pairs,targets)
        n_right += correct
    return 100.0 * n_right / n_trials

# %%
ways = np.arange(1,20,2)
resume =  False
trials = 50

# %%
val_accs, train_accs,nn_accs = [], [], []
for N in ways:    
    val_accs.append(test_oneshot(model, N, trials, "val", verbose=True))
    train_accs.append(test_oneshot(model, N, trials, "train", verbose=True))
    nn_acc = test_nn_accuracy(N, trials)
    nn_accs.append(nn_acc)
    print ("NN Accuracy = ", nn_acc)
    print("---------------------------------------------------------------------------------------------------------------")
# Out:
# Evaluating model on 50 random 1 way one-shot learning tasks ...
#
# Got an average of 100.0% 1 way one-shot learning accuracy
#
# Evaluating model on 50 random 1 way one-shot learning tasks ...
#
# Got an average of 100.0% 1 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 1 way one-shot learning tasks ...
# NN Accuracy =  100.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 3 way one-shot learning tasks ...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in sqrt
# Got an average of 94.0% 3 way one-shot learning accuracy
#
# Evaluating model on 50 random 3 way one-shot learning tasks ...
#
# Got an average of 100.0% 3 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 3 way one-shot learning tasks ...
# NN Accuracy =  34.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 5 way one-shot learning tasks ...
#
# Got an average of 94.0% 5 way one-shot learning accuracy
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
#
# Got an average of 100.0% 5 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 5 way one-shot learning tasks ...
# NN Accuracy =  20.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 7 way one-shot learning tasks ...
#
# Got an average of 82.0% 7 way one-shot learning accuracy
#
# Evaluating model on 50 random 7 way one-shot learning tasks ...
#
# Got an average of 92.0% 7 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 7 way one-shot learning tasks ...
# NN Accuracy =  18.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 9 way one-shot learning tasks ...
#
# Got an average of 94.0% 9 way one-shot learning accuracy
#
# Evaluating model on 50 random 9 way one-shot learning tasks ...
#
# Got an average of 94.0% 9 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 9 way one-shot learning tasks ...
# NN Accuracy =  10.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 11 way one-shot learning tasks ...
#
# Got an average of 84.0% 11 way one-shot learning accuracy
#
# Evaluating model on 50 random 11 way one-shot learning tasks ...
#
# Got an average of 98.0% 11 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 11 way one-shot learning tasks ...
# NN Accuracy =  16.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 13 way one-shot learning tasks ...
#
# Got an average of 80.0% 13 way one-shot learning accuracy
#
# Evaluating model on 50 random 13 way one-shot learning tasks ...
#
# Got an average of 92.0% 13 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 13 way one-shot learning tasks ...
# NN Accuracy =  6.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 15 way one-shot learning tasks ...
#
# Got an average of 76.0% 15 way one-shot learning accuracy
#
# Evaluating model on 50 random 15 way one-shot learning tasks ...
#
# Got an average of 94.0% 15 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 15 way one-shot learning tasks ...
# NN Accuracy =  8.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 17 way one-shot learning tasks ...
#
# Got an average of 74.0% 17 way one-shot learning accuracy
#
# Evaluating model on 50 random 17 way one-shot learning tasks ...
#
# Got an average of 96.0% 17 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 17 way one-shot learning tasks ...
# NN Accuracy =  8.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 19 way one-shot learning tasks ...
#
# Got an average of 64.0% 19 way one-shot learning accuracy
#
# Evaluating model on 50 random 19 way one-shot learning tasks ...
#
# Got an average of 88.0% 19 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 19 way one-shot learning tasks ...
# NN Accuracy =  2.0
# ---------------------------------------------------------------------------------------------------------------

# %%
with open(os.path.join(save_path,"accuracies.pickle"), "wb") as f:
    pickle.dump((val_accs,train_accs,nn_accs),f)

# %%
with open(os.path.join(save_path, "accuracies.pickle"), "rb") as f:
    (val_accs, train_accs, nn_accs) = pickle.load(f)

# %%
def concat_images(X):
    """Concatenates a bunch of images into a big matrix for plotting purposes."""
    nc, h , w, _ = X.shape
    X = X.reshape(nc, h, w)
    n = np.ceil(np.sqrt(nc)).astype("int8")
    img = np.zeros((n*w,n*h))
    x = 0
    y = 0
    for example in range(nc):
        img[x*w:(x+1)*w,y*h:(y+1)*h] = X[example]
        y += 1
        if y >= n:
            y = 0
            x += 1
    return img

# %%
def plot_oneshot_task(pairs):
    fig,(ax1,ax2) = plt.subplots(nrows=1, ncols=2)
    ax1.matshow(pairs[0][0].reshape(105,105), cmap='gray')
    img = concat_images(pairs[1])
    ax1.get_yaxis().set_visible(False)
    ax1.get_xaxis().set_visible(False)
    ax2.matshow(img,cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %%
# Example of concat image visualization
pairs, targets = make_oneshot_task(16,"train","Sanskrit")
plot_oneshot_task(pairs)

# %%
fig,ax = plt.subplots(1)
ax.plot(ways, val_accs, "m", label="Siamese(val set)")
ax.plot(ways, train_accs, "y", label="Siamese(train set)")
plt.plot(ways, nn_accs, label="Nearest neighbour")

ax.plot(ways, 100.0/ways, "g", label="Random guessing")
plt.xlabel("Number of possible classes in one-shot tasks")
plt.ylabel("% Accuracy")
plt.title("Omiglot One-Shot Learning Performance of a Siamese Network")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
inputs,targets = make_oneshot_task(20, "val", 'Oriya')
plt.show()

plot_oneshot_task(inputs)
